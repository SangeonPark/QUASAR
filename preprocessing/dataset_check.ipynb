# %%
import numpy as np
import matplotlib.pyplot as plt
import h5py
import pandas as pd

# %%
pd.set_option('display.max_columns', None)

# %%
df = pd.read_hdf('nsubjettiness_massratio_rnd.h5')

# %%
df.head()
# Out:
#            Mjj         Mj1  j1 tau1(b=.5)  j1 tau1(b=1)  j1 tau1(b=2)  \
# 0  2577.571899   98.677270       0.053375      0.022677      0.009253
# 1  3807.507389  584.595432       0.670141      0.490678      0.275638
# 2  1710.965414  159.597526       0.418784      0.241483      0.100078
# 3  2603.379037  515.237299       0.483659      0.435741      0.230891
# 4  3294.162200  142.420213       0.203619      0.087964      0.026577
#
#    j1 tau2(b=.5)  j1 tau2(b=1)  j1 tau2(b=2)  j1 tau3(b=.5)  j1 tau3(b=1)  \
# 0       0.042518      0.011994      0.002307       0.038869      0.009455
# 1       0.331875      0.169591      0.060717       0.231046      0.078599
# 2       0.343810      0.163651      0.051971       0.258793      0.113035
# 3       0.141166      0.039669      0.008714       0.114992      0.031118
# 4       0.149224      0.044661      0.006325       0.091160      0.023344
#
#    j1 tau3(b=2)  j1 tau4(b=.5)  j1 tau4(b=1)  j1 tau4(b=2)  j1 tau5(b=.5)  \
# ...

# %%
df["j1 tau15(b=1)"]
# Out:
# 0       0.002449
# 1       0.025031
# 2       0.032967
# 3       0.010256
# 4       0.009595
#           ...
# 4995    0.001919
# 4996    0.002217
# 4997    0.021558
# 4998    0.011694
# 4999    0.006306
# Name: j1 tau15(b=1), Length: 5000, dtype: float64

# %%
df = f.values

# %%
df[0]
# Out:
# array([2.57757190e+03, 9.86772703e+01, 5.33747599e-02, 2.26769809e-02,
#        9.25313985e-03, 4.25183682e-02, 1.19939337e-02, 2.30668053e-03,
#        3.88693349e-02, 9.45458792e-03, 1.53995143e-03, 3.68175167e-02,
#        8.55140058e-03, 1.13368894e-03, 3.49728366e-02, 7.53865717e-03,
#        9.34730792e-04, 3.26000794e-02, 6.87262274e-03, 8.62374920e-04,
#        3.13367130e-02, 5.97757629e-03, 5.59877857e-04, 2.98660952e-02,
#        5.25179731e-03, 4.03486500e-04, 2.57730806e-02, 4.79546238e-03,
#        3.96718728e-04, 2.37788457e-02, 4.30111808e-03, 3.55421952e-04,
#        2.26644997e-02, 3.93373325e-03, 3.04495653e-04, 2.15035034e-02,
#        3.43099345e-03, 2.36180923e-04, 1.88260435e-02, 3.03431015e-03,
#        2.27231947e-04, 1.80946486e-02, 2.69153825e-03, 1.76494237e-04,
#        1.70255262e-02, 2.44947388e-03, 1.64968414e-04, 1.36000000e+02,
#        1.28589595e+03, 1.88817651e+01, 9.79773305e+00, 5.44031844e-01,
# ...
